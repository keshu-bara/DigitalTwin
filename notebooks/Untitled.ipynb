# %%
import json

# %%
with open("../data/processed/messages.json","r",encoding="utf-8") as f:
    messages = json.load(f) #loading json formate as python dic formate

len(messages)
# Out:
# 1326

# %%
TARGET_SPEAKER = " Nikhil Mishra CE" #target speaker

# %%
messages[0]
# Out:
# {'timestamp': '08/09/2024, 7:57\u202fpm ',
#  'speaker': ' Keshav Barawal',
#  'text': 'hlo'}

# %%
messages[1]
# Out:
# {'timestamp': '08/09/2024, 7:58\u202fpm ',
#  'speaker': ' Keshav Barawal',
#  'text': '130 the na??'}

# %%
messages
# Out:
# [{'timestamp': '08/09/2024, 7:57\u202fpm ',
#   'speaker': ' Keshav Barawal',
#   'text': 'hlo'},
#  {'timestamp': '08/09/2024, 7:58\u202fpm ',
#   'speaker': ' Keshav Barawal',
#   'text': '130 the na??'},
#  {'timestamp': '08/09/2024, 7:58\u202fpm ',
#   'speaker': ' Keshav Barawal',
#   'text': '130 the na??'},
#  {'timestamp': '08/09/2024, 8:11\u202fpm ',
#   'speaker': ' Nikhil Mishra CE',
#   'text': 'bhai tu charge bacha, ye sab baad mein bhi ho jata. 😅'},
#  {'timestamp': '08/09/2024, 8:13\u202fpm ',
#   'speaker': ' Keshav Barawal',
#   'text': 'Hn bhai laptop se lagya h abhi😂'},
#  {'timestamp': '08/09/2024, 8:24\u202fpm ',
#   'speaker': ' Nikhil Mishra CE',
#   'text': '👌😂'},
#  {'timestamp': '08/09/2024, 8:24\u202fpm ',
#   'speaker': ' Nikhil Mishra CE',
#   'text': '👌😂'},
#  {'timestamp': '14/09/2024, 1:20\u202fpm ',
#   'speaker': ' Nikhil Mishra CE',
#   'text': 'agar cringe na lag raha ho tho forward karde 😅'},
#  {'timestamp': '14/09/2024, 1:21\u202fpm ',
# ...

# %%
merged_messages = []

current_block = messages[0]

for i in range(1, len(messages)):

    msg = messages[i]

    # if same speaker as previous -> merge it
    if msg['speaker'] == current_block['speaker']:
        current_block['text'] += " " + msg["text"]

    else:
        # Different speaker -> save the previous block
        merged_messages.append(current_block)
        current_block = msg

# Append last block
merged_messages.append(current_block)

print(len(merged_messages),len(messages))
print(merged_messages)
# Out:
# 685 1326
# ...

# %%
training_data = []



for i in range(1,len(messages)):

    current_msg = messages[i]
    previous_msg = messages[i - 1]

    if current_msg['speaker'] == TARGET_SPEAKER:

        context_messages = []


        for j in range(i-
