# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from DataIngestionPipeline.rag_dataprocessing_pipeline import rag_dataprocessing_pipeline
#       3 rag_dataprocessing_pipeline("../data/raw_chats", 'Keshav Barawal', "../data/rag_memory/processeddata.json")
#
# ModuleNotFoundError: No module named 'DataIngestionPipeline.rag_dataprocessing_pipeline'
