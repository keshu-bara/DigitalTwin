# %%
from dataprocessing_pipeline import finetune_dataprocessing_pipeline

# %%
finetune_dataprocessing_pipeline("../data/raw_chats","Keshav Barawal","../data/processed.json")
# Out:
# INFO:root:Processing file: Devesh.txt
# INFO:root:Processing file: Vinayak.txt
# INFO:root:Processing file: WhatsApp Chat with Dhruv.txt
# INFO:root:Processing file: WhatsApp Chat with Ketan Saini CE DS.txt
# INFO:root:Processing file: WhatsApp Chat with Officer.txt
# INFO:root:Processing file: WhatsApp Chat with Satvik.txt
# INFO:root:Data Processing done.
# INFO:root:All files processed.
# RAG memory units created: 2061

# %%
# Out:
# [{'timestamp': '11/11/2023, 10:17\u202fam',
#   'speaker': 'Keshav Barawal',
#   'text': 'Ek brr hoddie wale grp ka link bhej yo'},
#  {'timestamp': '11/11/2023, 10:45\u202fam',
#   'speaker': 'Devesh',
#   'text': 'Ni hai bhai link to ese'},
#  {'timestamp': '12/03/2024, 4:56\u202fpm',
#   'speaker': 'Keshav Barawal',
#   'text': 'Hlo'},
#  {'timestamp': '12/03/2024, 5:00\u202fpm',
#   'speaker': 'Devesh',
#   'text': 'Yo hii ✌🏻'},
#  {'timestamp': '12/03/2024, 5:01\u202fpm',
#   'speaker': 'Keshav Barawal',
#   'text': 'Bhai flat leyga?\nYa leleya'},
#  {'timestamp': '12/03/2024, 5:02\u202fpm',
#   'speaker': 'Devesh',
#   'text': 'Lia to ni abhi yr'},
#  {'timestamp': '12/03/2024, 5:02\u202fpm',
#   'speaker': 'Keshav Barawal',
#   'text': 'Arre mein aur mera roommate hn?\n2 bnnde'},
#  {'timestamp': '12/03/2024, 5:03\u202fpm',
#   'speaker': 'Devesh',
#   'text': 'Maii yr puchke btata hu trko wse to hai humlog abhi full\nKisi ne mna kra to bta dunga mai trko'},
# ...
